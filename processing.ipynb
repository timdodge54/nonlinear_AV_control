# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# import output.csv

df = pd.read_csv('output.csv')
print(df.head())
# calculate the angular accelaeration from the angular velocity and time
# get the first
df['angular_acceleration'] = df['AngularVelocityZ'].diff() / .01
print(df.head())
# add 0 to the  first row of the angular acceleration column
df['angular_acceleration'] = df['angular_acceleration'].fillna(0)
print(df.head())
# plot the angular acceleration
df['angular_acceleration'].plot()
# save the data frame as output_acceleration.csv
df.to_csv('output_acceleration.csv', index=False)
# Out:
#         Yaw      PosX      PosY  VelocityNorm  AngularVelocityZ  Time
# 0  7.592081  8.200000 -5.500000             5      1.286560e-09  0.00
# 1  7.591971  8.249562 -5.493394             5     -2.203060e-02  0.01
# 2  7.591640  8.299123 -5.486788             5     -4.406121e-02  0.02
# 3  7.591089  8.348685 -5.480183             5     -6.609181e-02  0.03
# 4  7.590318  8.398247 -5.473578             5     -8.812241e-02  0.04
#         Yaw      PosX      PosY  VelocityNorm  AngularVelocityZ  Time  \
# 0  7.592081  8.200000 -5.500000             5      1.286560e-09  0.00
# 1  7.591971  8.249562 -5.493394             5     -2.203060e-02  0.01
# 2  7.591640  8.299123 -5.486788             5     -4.406121e-02  0.02
# 3  7.591089  8.348685 -5.480183             5     -6.609181e-02  0.03
# 4  7.590318  8.398247 -5.473578             5     -8.812241e-02  0.04
#
#    angular_acceleration
# 0                   NaN
# 1              -2.20306
# 2              -2.20306
# 3              -2.20306
# 4              -2.20306
#         Yaw      PosX      PosY  VelocityNorm  AngularVelocityZ  Time  \
# 0  7.592081  8.200000 -5.500000             5      1.286560e-09  0.00
# 1  7.591971  8.249562 -5.493394             5     -2.203060e-02  0.01
# 2  7.591640  8.299123 -5.486788             5     -4.406121e-02  0.02
# 3  7.591089  8.348685 -5.480183             5     -6.609181e-02  0.03
# 4  7.590318  8.398247 -5.473578             5     -8.812241e-02  0.04
#
#    angular_acceleration
# 0               0.00000
# 1              -2.20306
# 2              -2.20306
# 3              -2.20306
# 4              -2.20306
